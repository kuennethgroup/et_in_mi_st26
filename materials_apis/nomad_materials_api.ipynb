# %% [markdown]
# # NOMAD Materials Database API Access
#
# In this notebook you should learn how to query data from the NOMAD (Fair Data Infrastructure for Materials Science) repository API.
#
# 1. You need to have the Python package `nomad-lab` installed. It is already installed in the environment (that lives @ .venv directory) and you can directly import it in your code. Using
#
# ```python
# from nomad.client.archive import ArchiveQuery
# ```
#
# 2. Read through the [How to access processed data in NOMAD](https://nomad-lab.eu/prod/v1/docs/howto/manage/program/archive_query.html) to understand how to query the database. You can use the `ArchiveQuery` class to perform queries.
#
# 3. Query the database for the first 200 VASP calculations on materials containing Oxygen (O).

# %%
from nomad.client.archive import ArchiveQuery
import pandas as pd
