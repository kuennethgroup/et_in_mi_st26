# %% [markdown]
# # Materials Project Database API Access
#
# In this notebook you should learn how to query data from the Materials Project repo.
#
# 1. You need to have the Python package `pymatgen` installed. It is already installed in the environment (that lives @ .venv directory) and you can directly import it in your code.
#
# 2. Obtain an updated API key at https://materialsproject.org/dashboard. It's for free, but you need to create an account with you university email address.
#
# 3. Read through https://pymatgen.org/usage.html#pymatgenextmatproj---integration-with-the-materials-project-rest-api
#
# 4. Query a dataset of 30 entries that contain Titanium Oxide (TiO2). You can use the `MPRester` class to perform queries.
#
# 5. Create a pandas dataframe from it and plot a histogram of the energies with matplotlib. You can use the `PhaseDiagram` and `PDPlotter` classes to plot the phase diagram of the system.
#
# 6. What's the unit of the energies? How can you convert it to joules?
